# %% [markdown]
# ## **Inference for emotion recognition**

# %%
# !pip install -r '../input/test-data/requirements.txt'
# Out:
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from -r ../input/test-data/requirements.txt (line 1)) (2.0.3)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from -r ../input/test-data/requirements.txt (line 2)) (1.24.3)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from -r ../input/test-data/requirements.txt (line 3)) (1.2.2)
# Requirement already satisfied: accelerate in /opt/conda/lib/python3.10/site-packages (from -r ../input/test-data/requirements.txt (line 4)) (0.26.1)
# Requirement already satisfied: peft in /opt/conda/lib/python3.10/site-packages (from -r ../input/test-data/requirements.txt (line 5)) (0.3.0)
# Requirement already satisfied: bitsandbytes in /opt/conda/lib/python3.10/site-packages (from -r ../input/test-data/requirements.txt (line 6)) (0.42.0)
# Requirement already satisfied: transformers in /opt/conda/lib/python3.10/site-packages (from -r ../input/test-data/requirements.txt (line 7)) (4.36.2)
# Requirement already satisfied: trl in /opt/conda/lib/python3.10/site-packages (from -r ../input/test-data/requirements.txt (line 8)) (0.7.9)
# Requirement already satisfied: huggingface_hub in /opt/conda/lib/python3.10/site-packages (from -r ../input/test-data/requirements.txt (line 9)) (0.20.2)
# Requirement already satisfied: datasets in /opt/conda/lib/python3.10/site-packages (from -r ../input/test-data/requirements.txt (line 10)) (2.1.0)
# Requirement already satisfied: wandb in /opt/conda/lib/python3.10/site-packages (from -r ../input/test-data/requirements.txt (line 11)) (0.16.2)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from -r ../input/test-data/requirements.txt (line 12)) (3.7.4)
# Requirement already satisfied: seaborn in /opt/conda/lib/python3.10/site-packages (from -r ../input/test-data/requirements.txt (line 13)) (0.12.2)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (from -r ../input/test-data/requirements.txt (line 14)) (9.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->-r ../input/test-data/requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->-r ../input/test-data/requirements.txt (line 1)) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas->-r ../input/test-data/requirements.txt (line 1)) (2023.3)
# Requirement already satisfied: scipy>=1.3.2 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->-r ../input/test-data/requirements.txt (line 3)) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->-r ../input/test-data/requirements.txt (line 3)) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->-r ../input/test-data/requirements.txt (line 3)) (3.2.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from accelerate->-r ../input/test-data/requirements.txt (line 4)) (21.3)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from accelerate->-r ../input/test-data/requirements.txt (line 4)) (5.9.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from accelerate->-r ../input/test-data/requirements.txt (line 4)) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /opt/conda/lib/python3.10/site-packages (from accelerate->-r ../input/test-data/requirements.txt (line 4)) (2.0.0)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/conda/lib/python3.10/site-packages (from accelerate->-r ../input/test-data/requirements.txt (line 4)) (0.4.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from transformers->-r ../input/test-data/requirements.txt (line 7)) (3.12.2)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers->-r ../input/test-data/requirements.txt (line 7)) (2023.8.8)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from transformers->-r ../input/test-data/requirements.txt (line 7)) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /opt/conda/lib/python3.10/site-packages (from transformers->-r ../input/test-data/requirements.txt (line 7)) (0.15.0)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers->-r ../input/test-data/requirements.txt (line 7)) (4.66.1)
# Requirement already satisfied: tyro>=0.5.11 in /opt/conda/lib/python3.10/site-packages (from trl->-r ../input/test-data/requirements.txt (line 8)) (0.6.6)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface_hub->-r ../input/test-data/requirements.txt (line 9)) (2023.12.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface_hub->-r ../input/test-data/requirements.txt (line 9)) (4.5.0)
# Requirement already satisfied: pyarrow>=5.0.0 in /opt/conda/lib/python3.10/site-packages (from datasets->-r ../input/test-data/requirements.txt (line 10)) (11.0.0)
# Requirement already satisfied: dill in /opt/conda/lib/python3.10/site-packages (from datasets->-r ../input/test-data/requirements.txt (line 10)) (0.3.7)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.10/site-packages (from datasets->-r ../input/test-data/requirements.txt (line 10)) (3.4.1)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.10/site-packages (from datasets->-r ../input/test-data/requirements.txt (line 10)) (0.70.15)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from datasets->-r ../input/test-data/requirements.txt (line 10)) (3.8.5)
# Requirement already satisfied: responses<0.19 in /opt/conda/lib/python3.10/site-packages (from datasets->-r ../input/test-data/requirements.txt (line 10)) (0.18.0)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /opt/conda/lib/python3.10/site-packages (from wandb->-r ../input/test-data/requirements.txt (line 11)) (8.1.7)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb->-r ../input/test-data/requirements.txt (line 11)) (3.1.32)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb->-r ../input/test-data/requirements.txt (line 11)) (1.39.1)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from wandb->-r ../input/test-data/requirements.txt (line 11)) (0.4.0)
# Requirement already satisfied: setproctitle in /opt/conda/lib/python3.10/site-packages (from wandb->-r ../input/test-data/requirements.txt (line 11)) (1.3.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from wandb->-r ../input/test-data/requirements.txt (line 11)) (68.1.2)
# Requirement already satisfied: appdirs>=1.4.3 in /opt/conda/lib/python3.10/site-packages (from wandb->-r ../input/test-data/requirements.txt (line 11)) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /opt/conda/lib/python3.10/site-packages (from wandb->-r ../input/test-data/requirements.txt (line 11)) (3.20.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->-r ../input/test-data/requirements.txt (line 12)) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->-r ../input/test-data/requirements.txt (line 12)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->-r ../input/test-data/requirements.txt (line 12)) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->-r ../input/test-data/requirements.txt (line 12)) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->-r ../input/test-data/requirements.txt (line 12)) (3.0.9)
# Requirement already satisfied: six>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from docker-pycreds>=0.4.0->wandb->-r ../input/test-data/requirements.txt (line 11)) (1.16.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->-r ../input/test-data/requirements.txt (line 10)) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->-r ../input/test-data/requirements.txt (line 10)) (3.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->-r ../input/test-data/requirements.txt (line 10)) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->-r ../input/test-data/requirements.txt (line 10)) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->-r ../input/test-data/requirements.txt (line 10)) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->-r ../input/test-data/requirements.txt (line 10)) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets->-r ../input/test-data/requirements.txt (line 10)) (1.3.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from GitPython!=3.1.29,>=1.0.0->wandb->-r ../input/test-data/requirements.txt (line 11)) (4.0.10)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->transformers->-r ../input/test-data/requirements.txt (line 7)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->transformers->-r ../input/test-data/requirements.txt (line 7)) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->transformers->-r ../input/test-data/requirements.txt (line 7)) (2023.11.17)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate->-r ../input/test-data/requirements.txt (line 4)) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate->-r ../input/test-data/requirements.txt (line 4)) (3.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate->-r ../input/test-data/requirements.txt (line 4)) (3.1.2)
# Requirement already satisfied: docstring-parser>=0.14.1 in /opt/conda/lib/python3.10/site-packages (from tyro>=0.5.11->trl->-r ../input/test-data/requirements.txt (line 8)) (0.15)
# Requirement already satisfied: rich>=11.1.0 in /opt/conda/lib/python3.10/site-packages (from tyro>=0.5.11->trl->-r ../input/test-data/requirements.txt (line 8)) (13.5.2)
# Requirement already satisfied: shtab>=1.5.6 in /opt/conda/lib/python3.10/site-packages (from tyro>=0.5.11->trl->-r ../input/test-data/requirements.txt (line 8)) (1.6.5)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb->-r ../input/test-data/requirements.txt (line 11)) (5.0.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich>=11.1.0->tyro>=0.5.11->trl->-r ../input/test-data/requirements.txt (line 8)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich>=11.1.0->tyro>=0.5.11->trl->-r ../input/test-data/requirements.txt (line 8)) (2.16.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.10.0->accelerate->-r ../input/test-data/requirements.txt (line 4)) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.10.0->accelerate->-r ../input/test-data/requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro>=0.5.11->trl->-r ../input/test-data/requirements.txt (line 8)) (0.1.2)

# %%
# !pip install peft==0.3.0
# Out:
# Requirement already satisfied: peft==0.3.0 in /opt/conda/lib/python3.10/site-packages (0.3.0)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from peft==0.3.0) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from peft==0.3.0) (21.3)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from peft==0.3.0) (5.9.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from peft==0.3.0) (6.0.1)
# Requirement already satisfied: torch>=1.13.0 in /opt/conda/lib/python3.10/site-packages (from peft==0.3.0) (2.0.0)
# Requirement already satisfied: transformers in /opt/conda/lib/python3.10/site-packages (from peft==0.3.0) (4.36.2)
# Requirement already satisfied: accelerate in /opt/conda/lib/python3.10/site-packages (from peft==0.3.0) (0.26.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->peft==0.3.0) (3.0.9)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.13.0->peft==0.3.0) (3.12.2)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=1.13.0->peft==0.3.0) (4.5.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.13.0->peft==0.3.0) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.13.0->peft==0.3.0) (3.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.13.0->peft==0.3.0) (3.1.2)
# Requirement already satisfied: huggingface-hub in /opt/conda/lib/python3.10/site-packages (from accelerate->peft==0.3.0) (0.20.2)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/conda/lib/python3.10/site-packages (from accelerate->peft==0.3.0) (0.4.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers->peft==0.3.0) (2023.8.8)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from transformers->peft==0.3.0) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /opt/conda/lib/python3.10/site-packages (from transformers->peft==0.3.0) (0.15.0)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers->peft==0.3.0) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub->accelerate->peft==0.3.0) (2023.12.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.13.0->peft==0.3.0) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->transformers->peft==0.3.0) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->transformers->peft==0.3.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->transformers->peft==0.3.0) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->transformers->peft==0.3.0) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.13.0->peft==0.3.0) (1.3.0)

# %% [markdown]
# #### **Import Libraries**

# %%
from accelerate import Accelerator
import os
import torch
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    AutoConfig,
    BitsAndBytesConfig,
)
import time
import json
import matplotlib.pyplot as plt
import seaborn as sns
from torch.utils.data import Dataset, DataLoader
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# #### **Config**

# %%
# Params
class Config:
    def __init__(self) -> None:
        self.seed = 42
        self.speaker = True
        self.video = False
        self.audio = False

# %%
# Testing with emotion labels or without
with_labels = False

# %% [markdown]
# #### **Dataset Preprocessing and Preparation**
#
# * We will divide the real test dataset into groups consisting of 50 conversations each or nearly 500 utterances (samples) due to session limits.
# * There are total 664 conversations.
# * This leads to 664/50 = 13 groups.

# %%
def split_data(data_file):
    file = open(data_file)
    data = json.load(file)
    os.makedirs('../working/input', exist_ok=True)

    num_conv = len(data)
    count = 0
    files = []
    while count < num_conv:
        i = 0
        group = []
        # form groups of 50 conversations / 500 utterances
        while i < 50 and count < num_conv:
            group.append(data[count])
            count += 1
            i += 1
        save_file = "../working/input/" + "group"+str(round(count/50))+".json"
        files.append(save_file)
        with open(save_file, 'w') as f:
            f.write(json.dumps(group))
        print("Saved Group: {} Length: {}".format(round(count/50), len(group)))
    return files

# %%
def get_prompt(sample_data_point, speaker=False, video=False, audio=False):
	if speaker and video and audio:
		instruction = """Identify the emotion label of utterance {} out of the 7 emotions: joy, anger, disgust, fear, sadness, surprise, neutral. The video_captions for each utterance describe the video corresponding to the text and audio captions describe the audio.\nDon't give an explanation.\nOutput only one line in the format:\nutterance_id :: emotion_label""".format(sample_data_point["utterance_id"])
	elif speaker and video:
		instruction = """Identify the emotion label of utterance {} out of the 7 emotions: joy, anger, disgust, fear, sadness, surprise, neutral. The video_captions for each utterance describe the video corresponding to the text.\nDon't give an explanation.\nOutput only one line in the format:\nutterance_id :: emotion_label""".format(sample_data_point["utterance_id"])
	else:
		instruction = """Identify the emotion label of utterance {} out of the 7 emotions: joy, anger, disgust, fear, sadness, surprise, neutral.\nDon't give an explanation.\nOutput only one line in the format:\nutterance_id :: emotion_label""".format(sample_data_point["utterance_id"])

	return f"""<s>[INST]\n{sample_data_point['conversation']}{instruction}\n[/INST]\n"""

# %%
def get_prompt_and_out(sample_data_point, speaker=False, video=False, audio=False):
	if speaker and video and audio:
		instruction = """Identify the emotion label of utterance {} out of the 7 emotions: joy, anger, disgust, fear, sadness, surprise, neutral. The video_captions for each utterance describe the video corresponding to the text and audio captions describe the audio.\nDon't give an explanation.\nOutput only one line in the format:\nutterance_id :: emotion_label""".format(sample_data_point["utterance_id"])
	elif speaker and video:
		instruction = """Identify the emotion label of utterance {} out of the 7 emotions: joy, anger, disgust, fear, sadness, surprise, neutral. The video_captions for each utterance describe the video corresponding to the text.\nDon't give an explanation.\nOutput only one line in the format:\nutterance_id :: emotion_label""".format(sample_data_point["utterance_id"])
	else:
		instruction = """Identify the emotion label of utterance {} out of the 7 emotions: joy, anger, disgust, fear, sadness, surprise, neutral.\nDon't give an explanation.\nOutput only one line in the format:\nutterance_id :: emotion_label""".format(sample_data_point["utterance_id"])

	return f"""<s>[INST]\n{sample_data_point['conversation']}{instruction}\n[/INST]\n""", f"""utterance_{sample_data_point["utterance_id"]} :: {sample_data_point['emotion_label']}\n</s>"""

# %%
def get_formatted_conversation(data_sample, speaker=False, video=False, audio=False):
    conversation_str = '"conversation": [\n'
    for utt in data_sample["conversation"]:
        # conversation_str
        if speaker and video and audio:
            conversation_str += "{{\n\"utterance_ID\": {}\n\"text\": {}\n\"speaker\": {}\n\"video_caption\": {}\n\"audio_caption\": {}".format(utt["utterance_ID"], utt["text"], utt["speaker"], utt["video_caption"], utt["audio_caption"])
            conversation_str += "\n}\n"
        elif speaker and video:
            conversation_str += "{{\n\"utterance_ID\": {}\n\"text\": {}\n\"speaker\": {}\n\"video_caption\": {}".format(utt["utterance_ID"], utt["text"], utt["speaker"], utt["video_caption"])
            conversation_str += "\n}\n"
        elif speaker:
            conversation_str += "{{\n\"utterance_ID\": {}\n\"text\": {}\n\"speaker\": {}\n}}\n".format(utt["utterance_ID"], utt["text"], utt["speaker"])
        else:
            conversation_str += "{{\n\"utterance_ID\": {}\n\"text\": {}\n}}\n".format(utt["utterance_ID"], utt["text"])
    return conversation_str

# %%
def form_input(data_sample, utt_id, speaker=False, video=False, audio=False, with_labels=False):
    conversation_str = get_formatted_conversation(data_sample, speaker, video, audio)
    if with_labels:
        emotions_str = data_sample["conversation"][utt_id]["emotion"]
    sample_data_point = {} # has utterance_id, conversation, emotion_label

    sample_data_point["utterance_id"] = utt_id+1
    sample_data_point["conversation"] = conversation_str
    if with_labels:
        sample_data_point["emotion_label"] = emotions_str
    else:
        sample_data_point["emotion_label"] = ""
    sample_data_point["conversation_id"] = data_sample["conversation_ID"]
    return sample_data_point

# %%
def generate_inst_for_each_utt_of_conv(data_point, speaker=False, video=False, audio=False, with_labels=False):
    num_utt = len(data_point["conversation"])
    list_output_objects = []
    for i in range(num_utt):
        sample_data_point = form_input(data_point, i, speaker, video, audio, with_labels)
        if with_labels:
            inst, out = get_prompt_and_out(sample_data_point, speaker, video, audio)
        else:
            inst = get_prompt(sample_data_point, speaker, video, audio)

        if with_labels:
            obj = {
                "instruction": inst,
                "out": out,
                "text": inst + out,
                "conversation_id": data_point["conversation_ID"],
                "utterance_id": i + 1,
                "emotion": data_point["conversation"][i]["emotion"]
            }
        else:
            obj = {
                "instruction": inst,
                # "out": out,
                # "text": inst + out,
                "conversation_id": data_point["conversation_ID"],
                "utterance_id": i + 1,
                "emotion": ""
            }
        list_output_objects.append(obj)
    return list_output_objects

# %%
def process_dataset(data, speaker=False, video=False, audio=False, with_labels=False):
    # add emotion key in original dict
    if not with_labels:
        for conv in data:
            for utt in conv["conversation"]:
                utt["emotion"] = ""
    flattened_list = [element for sublist in map(lambda x: generate_inst_for_each_utt_of_conv(x, speaker, video, audio, with_labels), data) for element in sublist]
    ds = {}
    ds["instruction"] = [sample["instruction"] for sample in flattened_list]
    if with_labels:
        ds["out"] = [sample["out"] for sample in flattened_list]
        ds["text"] = [sample["text"] for sample in flattened_list]
    ds["conversation_id"] = [sample["conversation_id"] for sample in flattened_list]
    ds["utterance_id"] = [sample["utterance_id"] for sample in flattened_list]
    ds["emotion"] = [sample["emotion"] for sample in flattened_list]
    return ds

# %%
config = Config()
data_file = "../input/test-data/Subtask_2_test.json"
# files = split_data(data_file)

# %% [markdown]
# #### **Load according to group number**

# %%
# Load one group of conversations
# group_num = 0
# data_file = files[group_num]
with open(data_file, 'r') as f:
    data = json.load(f)

# %%
# Form datasets from data
dataset = process_dataset(data, speaker=True, with_labels=with_labels)

# %%
# Total number of samples
n = len(dataset["instruction"])
print(n)
# Out:
# 6301

# %%
print(dataset["instruction"][0])
# Out:
# <s>[INST]
# "conversation": [
# {
# "utterance_ID": 1
# "text": Please do not do that again . It is a horrible sound .
# "speaker": Chandler
# }
# {
# "utterance_ID": 2
# "text": Uh , it is Paul .
# "speaker": Paul
# }
# {
# "utterance_ID": 3
# "text": Buzz him in .
# "speaker": Monica
# }
# {
# "utterance_ID": 4
# "text": Who is Paul ?
# "speaker": Joey
# }
# {
# "utterance_ID": 5
# "text": Paul , the wine guy , Paul ?
# "speaker": Ross
# }
# {
# "utterance_ID": 6
# "text": Maybe .
# "speaker": Monica
# }
# {
# "utterance_ID": 7
# "text": Wait a minute . Your " not a real date " is with Paul , the wine guy ?
# "speaker": Joey
# }
# {
# "utterance_ID": 8
# "text": He finally asked you out ?
# "speaker": Ross
# }
# {
# "utterance_ID": 9
# "text": Yes .
# "speaker": Monica
# }
# {
# "utterance_ID": 10
# "text": Ooh . This is a " Dear Diary " moment .
# "speaker": Chandler
# }
# {
# "utterance_ID": 11
# "text": Rach , wait , I can cancel .
# "speaker": Monica
# }
# {
# "utterance_ID": 12
# "text": Please , no . Go , I will be fine .
# "speaker": Rachel
# }
# {
# "utterance_ID": 13
# "text": Ross , are you okay ? I mean , do you want me to stay ?
# "speaker": Monica
# }
# {
# "utterance_ID": 14
# "text": That would be good .
# "speaker": Ross
# }
# {
# "utterance_ID": 15
# "text": Really ?
# "speaker": Monica
# }
# {
# "utterance_ID": 16
# "text": No , go on ! It is Paul , the wine guy .
# "speaker": Ross
# }
# Identify the emotion label of utterance 1 out of the 7 emotions: joy, anger, disgust, fear, sadness, surprise, neutral.
# Don't give an explanation.
# Output only one line in the format:
# utterance_id :: emotion_label
# [/INST]

# %% [markdown]
# #### **Loading fine-tuned model saved on Huggingface Hub**

# %%
# !python -c "from huggingface_hub.hf_api import HfFolder; HfFolder.save_token('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')"

# %%
# !pip install -U bitsandbytes accelerate
# Out:
# Requirement already satisfied: bitsandbytes in /opt/conda/lib/python3.10/site-packages (0.42.0)
# Requirement already satisfied: accelerate in /opt/conda/lib/python3.10/site-packages (0.26.1)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from bitsandbytes) (1.11.4)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from accelerate) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from accelerate) (21.3)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from accelerate) (5.9.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /opt/conda/lib/python3.10/site-packages (from accelerate) (2.0.0)
# Requirement already satisfied: huggingface-hub in /opt/conda/lib/python3.10/site-packages (from accelerate) (0.20.2)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/conda/lib/python3.10/site-packages (from accelerate) (0.4.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->accelerate) (3.0.9)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.12.2)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (4.5.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub->accelerate) (2023.12.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub->accelerate) (4.66.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub->accelerate) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub->accelerate) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub->accelerate) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub->accelerate) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)

# %%
from peft import PeftModel, PeftConfig
from transformers import AutoModelForCausalLM, AutoTokenizer

# Load peft config for pre-trained checkpoint
peft_model_id = "ArefaMuzaffar/merged-llama-emotion-text"
# config = PeftConfig.from_pretrained(peft_model_id)

compute_dtype = getattr(torch, "float16")
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4", # 4-bit quantized noraml float
    bnb_compute_dtype=compute_dtype,
    llm_int8_enable_fp32_cpu_offload=True,
)

model = AutoModelForCausalLM.from_pretrained(peft_model_id,
                                             return_dict=True,
                                             device_map="auto",
                                             offload_folder="/tmp/.offload",
                                             quantization_config= bnb_config,
                                            )
tokenizer = AutoTokenizer.from_pretrained(peft_model_id, use_fast=True)
# model = PeftModel.from_pretrained(model, peft_model_id)

model.config.use_cache = True
model.eval()

tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"

print("Peft model loaded")
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Peft model loaded

# %% [markdown]
# #### **Functions for parsing the output**
#
# Since this is causal LM the output generated is text which needs to be parsed to get the emotion label.

# %%
# Functions for parsing the output
import string

uppercase_set = set(string.ascii_uppercase)
lowercase_set = set(string.ascii_lowercase)
chars = uppercase_set.union(lowercase_set)

# %%
def extract_emotion_label(pred_label):
    """
    Extracts the first word after occurence of ::
    pred_label is raw output string from the model
    Example: "utterance_id :: anger ..."
    It could be inconsistent.
    """
    if len(pred_label.split("::")) >= 2:
        label = pred_label.split("::")[1]
    else:
        return ""
    label = label.strip()
    out_label = ""
    for c in label:
        if c not in chars:
            break
        out_label += c
    return out_label

# %%
import re
def extract_first_emotion(pred_str):
    target_strings = ["anger", "fear", "joy", "disgust", "sadness", "surprise", "neutral"]
    pattern = re.compile('|'.join(map(re.escape, target_strings)))
    # Find the first match
    match = pattern.search(pred_str)
    if match:
        # print(f"Found emotion: {match.group()}")
        # print(f"Index: {match.start()}")
        return match.group()
    else:
        # print("No emotion found.")
        return ""

# %%
# Define folder for saving the output
if with_labels:
    eval_results_folder = "../working/results_train"
    if not os.path.exists(eval_results_folder):
        os.makedirs(eval_results_folder)
else:
    eval_results_folder = "../working/results_test"
    if not os.path.exists(eval_results_folder):
        os.makedirs(eval_results_folder)

# %%
# Dataloader for batched inference
class InferenceDataset(Dataset):
    def __init__(self, dataset, tokenizer):
        self.dataset = dataset
        self.tokenizer = tokenizer

    def __len__(self):
        return len(self.dataset["instruction"])

    def __getitem__(self, idx):
        instruction = self.dataset["instruction"][idx]
        return instruction

# %% [markdown]
# #### **4 functions for getting outputs**
#
# * We can do inference with or without labels.
# * With labels for getting metrics on the provided dataset with labels.
# * Without for the actual evaluation data.
# * We can do batched inference.

# %%
# Get full output for entire dataset, batched inference
def get_full_output_batched(dataset, batch_size=2):
    init_time = time.time()
    inference_dataset = InferenceDataset(dataset, tokenizer)

    data_loader = DataLoader(inference_dataset, batch_size=batch_size, shuffle=False)

    outputs_list = []

    model.eval()
    i = 0
    with torch.no_grad():
        for batch_item in data_loader:
            start_time = time.time()
            instructions = batch_item
            print("------------------------------------")
            print(f"Iteration {i}")
            print("------------------------------------")
            i += 1
            tokenized_instruction = tokenizer(instructions, return_tensors="pt", padding=True, truncation=True, max_length=3000)
            input_ids = tokenized_instruction["input_ids"].cuda()

            outputs = model.generate(input_ids=input_ids, max_new_tokens=15) # max_new_tokens is to limit the num of tokens added to orig input
            # since we only want to add utterance_id :: emotion_label we may set it to 20

            decoded_outputs = tokenizer.batch_decode(outputs.detach().cpu().numpy(), skip_special_tokens=True)
            end_time = time.time()
            print("Inference time for one sample: {:.2f} seconds".format((end_time - start_time)/batch_size))
            outputs_list.extend(decoded_outputs)
    final_time = time.time()
    print("Total time for {} samples using batched inferencing = {} seconds.".format(n, final_time - init_time))
    return outputs_list

# %%
full_output = []
pred_labels_list = []
true_labels_list = []
correct = 0

# %%
def evaluate_with_label_batched(dataset):   
    full_output = get_full_output_batched(dataset)
    correct = 0
    # extract the label from text, !without shuffle
    for i in range(len(dataset["instruction"])):
        print("------------------------------------")
        print(f"Iteration {i}")
        print("------------------------------------")
        output = full_output[i]
        # extract
        if len(output.split("utterance_id :: emotion_label")) == 1:
            output = extract_first_emotion(output.lower())
            pred_labels_list.append(output)
            print("Predicted: ", output)
        else:
            output = output.split("utterance_id :: emotion_label")[1]
            output = extract_emotion_label(output.strip())
            output = output.strip().lower()
            pred_labels_list.append(output)
            print("Predicted: ", output)
        # baseline
        baseline_output = dataset["out"][i]
        baseline_output = extract_emotion_label(baseline_output.strip())
        baseline_output = baseline_output.strip().lower()
        print("Baseline: ", baseline_output)
        true_labels_list.append(baseline_output)
        # Accuracy
        if output == baseline_output:
            print("Correct")
            correct += 1
        else:
            print("Incorrect")
        print("------------------------------------")

    print("------------------------------------")
    print("Accuracy: {}".format(correct / n))
    print("------------------------------------")

    # Save results
    with open(eval_results_folder + "/pred_text_batched.json", 'w', encoding="utf-8") as f:
        for string in full_output:
            f.write(f"{string}\n[/NEWNEW]\n")
    with open(eval_results_folder + "/pred_labels_batched.json", 'w', encoding="utf-8") as f:
        for i in range(len(pred_labels_list)):
            f.write(f'{pred_labels_list[i]}\n')
    with open(eval_results_folder + "/true_labels_batched.json", 'w', encoding="utf-8") as f:
        for i in range(len(true_labels_list)):
            f.write(f'{true_labels_list[i]}\n')
    return pred_labels_list, true_labels_list, full_output, correct

# %%
def evaluate_without_label_batched(dataset):   
    full_output = get_full_output_batched(dataset)
    
    # extract the label from text, !without shuffle
    for i in range(len(dataset["instruction"])):
        print("------------------------------------")
        print(f"Iteration {i}")
        print("------------------------------------")
        output = full_output[i]
        # extract
        if len(output.split("utterance_id :: emotion_label")) == 1:
            output = extract_first_emotion(output.lower())
            pred_labels_list.append(output)
            print("Predicted: ", output)
            dataset["emotion"][i] = output
        else:
            output = output.split("utterance_id :: emotion_label")[1]
            output = extract_emotion_label(output.strip())
            output = output.strip().lower()
            pred_labels_list.append(output)
            print("Predicted: ", output)
            dataset["emotion"][i] = output

    # Save results
    with open(eval_results_folder + "/pred_text_batched.json", 'w', encoding="utf-8") as f:
        for string in full_output:
            f.write(f"{string}\n[/NEWNEW]\n")
    return pred_labels_list, full_output

# %%
# Get output from model for single prompt
def get_full_output(prompt):
    start_time = time.time()
    with torch.inference_mode():
        input_ids = tokenizer(prompt, return_tensors='pt',truncation=True).input_ids.cuda()

        outputs = model.generate(input_ids=input_ids, max_new_tokens=15, )
        output = tokenizer.batch_decode(outputs.detach().cpu().numpy(), skip_special_tokens=True)[0]
    end_time = time.time()
    print("Inference time: {:.2f} seconds".format(end_time - start_time))
    return output

# %%
def evaluate_with_label(dataset):
    correct = 0
    
    for i in range(len(dataset["instruction"])):
        print("------------------------------------")
        print(f"Iteration {i}")
        print("------------------------------------")
        # predict
        prompt = dataset["instruction"][i]
        output = get_full_output(prompt)
        full_output.append(output)
        # extract
        if len(output.split("utterance_id :: emotion_label")) == 1:
            output = extract_first_emotion(output.lower())
            print("Predicted: ", output)
        else:
            output = output.split("utterance_id :: emotion_label")[1]
            output = extract_emotion_label(output.strip())
            output = output.strip().lower()
            pred_labels_list.append(output)
            print("Predicted: ", output)
        # baseline
        baseline_output = dataset["out"][i]
        baseline_output = extract_emotion_label(baseline_output.strip())
        baseline_output = baseline_output.strip().lower()
        print("Baseline: ", baseline_output)
        true_labels_list.append(baseline_output)
        # Accuracy
        if output == baseline_output:
            print("Correct")
            correct += 1
        else:
            print("Incorrect")
        print("------------------------------------")

    print("------------------------------------")
    print("Accuracy: {}".format(correct / n))
    print("------------------------------------")
    # Save results
    with open(eval_results_folder + "/pred_text.json", 'w', encoding="utf-8") as f:
        for string in full_output:
            f.write(f"{string}\n[/NEWNEW]\n")
    with open(eval_results_folder + "/pred_labels.json", 'w', encoding="utf-8") as f:
        for i in range(len(pred_labels_list)):
            f.write(f'{pred_labels_list[i]}\n')
    # Save baseline also
    with open(eval_results_folder + "/true_labels.json", 'w', encoding="utf-8") as f:
        for i in range(len(true_labels_list)):
            f.write(f'{true_labels_list[i]}\n')
    return pred_labels_list, true_labels_list, full_output, correct

# %%
def evaluate_without_label(dataset):    
    for i in range(len(dataset["instruction"])):
        print("------------------------------------")
        print(f"Iteration {i}")
        print("------------------------------------")
        # predict
        prompt = dataset["instruction"][i]
        output = get_full_output(prompt)
        full_output.append(output)
        # extract
        if len(output.split("utterance_id :: emotion_label")) == 1:
            output = extract_first_emotion(output.lower())
            print("Predicted: ", output)
            dataset["emotion"][i] = output
        else:
            output = output.split("utterance_id :: emotion_label")[1]
            output = extract_emotion_label(output.strip())
            output = output.strip().lower()
            pred_labels_list.append(output)
            print("Predicted: ", output)
            dataset["emotion"][i] = output

    # Save results
    with open(eval_results_folder + "/pred_text.json", 'w', encoding="utf-8") as f:
        for string in full_output:
            f.write(f"{string}\n[/NEWNEW]\n")
    return pred_labels_list, full_output

# %% [markdown]
# #### **Begin Inference**
#
# **Batched Inference**

# %%
# Batched inference
init_time = time.time()

if with_labels:
    evaluate_with_label_batched(dataset)
else:
    evaluate_without_label_batched(dataset)

final_time = time.time()
print("Total time taken for {} samples = {:.2f} seconds.".format(n, final_time - init_time))
# Out:
# ------------------------------------
# Iteration 0
# ------------------------------------
# Inference time for one sample: 2.71 seconds
# ------------------------------------
# Iteration 1
# ------------------------------------
# Inference time for one sample: 2.64 seconds
# ------------------------------------
# Iteration 2
# ------------------------------------
# Inference time for one sample: 2.71 seconds
# ------------------------------------
# Iteration 3
# ------------------------------------
# Inference time for one sample: 2.68 seconds
# ------------------------------------
# Iteration 4
# ------------------------------------
# Inference time for one sample: 2.96 seconds
# ------------------------------------
# Iteration 5
# ------------------------------------
# Inference time for one sample: 2.89 seconds
# ------------------------------------
# Iteration 6
# ------------------------------------
# Inference time for one sample: 2.88 seconds
# ------------------------------------
# Iteration 7
# ------------------------------------
# Inference time for one sample: 2.95 seconds
# ------------------------------------
# Iteration 8
# ------------------------------------
# Inference time for one sample: 2.45 seconds
# ------------------------------------
# Iteration 9
# ------------------------------------
# Inference time for one sample: 2.47 seconds
# ------------------------------------
# Iteration 10
# ------------------------------------
# Inference time for one sample: 2.40 seconds
# ------------------------------------
# Iteration 11
# ------------------------------------
# Inference time for one sample: 2.42 seconds
# ------------------------------------
# Iteration 12
# ------------------------------------
# Inference time for one sample: 2.88 seconds
# ------------------------------------
# Iteration 13
# ------------------------------------
# Inference time for one sample: 2.27 seconds
# ------------------------------------
# Iteration 14
# ------------------------------------
# Inference time for one sample: 2.29 seconds
# ------------------------------------
# Iteration 15
# ------------------------------------
# Inference time for one sample: 2.46 seconds
# ------------------------------------
# Iteration 16
# ------------------------------------
# Inference time for one sample: 2.33 seconds
# ------------------------------------
# Iteration 17
# ------------------------------------
# Inference time for one sample: 2.31 seconds
# ------------------------------------
# Iteration 18
# ------------------------------------
# Inference time for one sample: 2.36 seconds
# ------------------------------------
# Iteration 19
# ------------------------------------
# Inference time for one sample: 2.32 seconds
# ------------------------------------
# Iteration 20
# ------------------------------------
# Inference time for one sample: 2.41 seconds
# ------------------------------------
# Iteration 21
# ------------------------------------
# Inference time for one sample: 2.40 seconds
# ------------------------------------
# Iteration 22
# ------------------------------------
# Inference time for one sample: 2.34 seconds
# ------------------------------------
# Iteration 23
# ------------------------------------
# Inference time for one sample: 2.34 seconds
# ------------------------------------
# Iteration 24
# ------------------------------------
# Inference time for one sample: 2.33 seconds
# ------------------------------------
# Iteration 25
# ------------------------------------
# Inference time for one sample: 2.44 seconds
# ------------------------------------
# Iteration 26
# ------------------------------------
# Inference time for one sample: 2.40 seconds
# ------------------------------------
# Iteration 27
# ------------------------------------
# Inference time for one sample: 2.55 seconds
# ------------------------------------
# Iteration 28
# ------------------------------------
# Inference time for one sample: 2.45 seconds
# ------------------------------------
# Iteration 29
# ------------------------------------
# Inference time for one sample: 3.53 seconds
# ------------------------------------
# Iteration 30
# ------------------------------------
# Inference time for one sample: 3.16 seconds
# ------------------------------------
# Iteration 31
# ------------------------------------
# Inference time for one sample: 3.18 seconds
# ------------------------------------
# Iteration 32
# ------------------------------------
# Inference time for one sample: 3.25 seconds
# ------------------------------------
# Iteration 33
# ------------------------------------
# Inference time for one sample: 3.18 seconds
# ------------------------------------
# Iteration 34
# ------------------------------------
# Inference time for one sample: 3.80 seconds
# ------------------------------------
# Iteration 35
# ------------------------------------
# Inference time for one sample: 3.81 seconds
# ------------------------------------
# Iteration 36
# ------------------------------------
# Inference time for one sample: 3.81 seconds
# ------------------------------------
# Iteration 37
# ------------------------------------
# Inference time for one sample: 3.78 seconds
# ------------------------------------
# Iteration 38
# ------------------------------------
# Inference time for one sample: 3.78 seconds
# ------------------------------------
# Iteration 39
# ------------------------------------
# Inference time for one sample: 3.75 seconds
# ------------------------------------
# Iteration 40
# ------------------------------------
# Inference time for one sample: 3.84 seconds
# ------------------------------------
# Iteration 41
# ------------------------------------
# Inference time for one sample: 4.08 seconds
# ------------------------------------
# Iteration 42
# ------------------------------------
# Inference time for one sample: 2.47 seconds
# ------------------------------------
# Iteration 43
# ------------------------------------
# Inference time for one sample: 2.46 seconds
# ------------------------------------
# Iteration 44
# ------------------------------------
# Inference time for one sample: 2.54 seconds
# ------------------------------------
# Iteration 45
# ------------------------------------
# Inference time for one sample: 2.98 seconds
# ------------------------------------
# Iteration 46
# ------------------------------------
# Inference time for one sample: 2.72 seconds
# ------------------------------------
# Iteration 47
# ------------------------------------
# Inference time for one sample: 2.64 seconds
# ------------------------------------
# Iteration 48
# ------------------------------------
# Inference time for one sample: 2.69 seconds
# ------------------------------------
# Iteration 49
# ------------------------------------
# Inference time for one sample: 2.61 seconds
# ------------------------------------
# Iteration 50
# ------------------------------------
# Inference time for one sample: 2.51 seconds
# ------------------------------------
# Iteration 51
# ------------------------------------
# Inference time for one sample: 2.28 seconds
# ------------------------------------
# Iteration 52
# ------------------------------------
# Inference time for one sample: 2.33 seconds
# ------------------------------------
# Iteration 53
# ------------------------------------
# Inference time for one sample: 2.43 seconds
# ------------------------------------
# Iteration 54
# ------------------------------------
# Inference time for one sample: 2.36 seconds
# ------------------------------------
# Iteration 55
# ------------------------------------
# Inference time for one sample: 2.33 seconds
# ------------------------------------
# Iteration 56
# ------------------------------------
# Inference time for one sample: 2.38 seconds
# ------------------------------------
# Iteration 57
# ------------------------------------
# Inference time for one sample: 2.40 seconds
# ------------------------------------
# Iteration 58
# ------------------------------------
# Inference time for one sample: 2.44 seconds
# ------------------------------------
# Iteration 59
# ------------------------------------
# Inference time for one sample: 2.41 seconds
# ------------------------------------
# Iteration 60
# ------------------------------------
# Inference time for one sample: 2.57 seconds
# ------------------------------------
# Iteration 61
# ------------------------------------
# Inference time for one sample: 2.44 seconds
# ------------------------------------
# Iteration 62
# ------------------------------------
# Inference time for one sample: 2.45 seconds
# ------------------------------------
# Iteration 63
# ------------------------------------
# Inference time for one sample: 2.46 seconds
# ------------------------------------
# Iteration 64
# ------------------------------------
# Inference time for one sample: 2.48 seconds
# ------------------------------------
# Iteration 65
# ------------------------------------
# Inference time for one sample: 2.98 seconds
# ------------------------------------
# Iteration 66
# ------------------------------------
# Inference time for one sample: 2.93 seconds
# ------------------------------------
# Iteration 67
# ------------------------------------
# Inference time for one sample: 2.98 seconds
# ------------------------------------
# Iteration 68
# ------------------------------------
# Inference time for one sample: 2.94 seconds
# ------------------------------------
# Iteration 69
# ------------------------------------
# Inference time for one sample: 2.81 seconds
# ------------------------------------
# Iteration 70
# ------------------------------------
# Inference time for one sample: 2.74 seconds
# ------------------------------------
# Iteration 71
# ------------------------------------
# Inference time for one sample: 2.75 seconds
# ------------------------------------
# Iteration 72
# ------------------------------------
# Inference time for one sample: 2.92 seconds
# ------------------------------------
# Iteration 73
# ------------------------------------
# Inference time for one sample: 2.97 seconds
# ------------------------------------
# Iteration 74
# ------------------------------------
# Inference time for one sample: 2.97 seconds
# ------------------------------------
# Iteration 75
# ------------------------------------
# Inference time for one sample: 2.98 seconds
# ------------------------------------
# Iteration 76
# ------------------------------------
# Inference time for one sample: 3.55 seconds
# ------------------------------------
# Iteration 77
# ------------------------------------
# Inference time for one sample: 3.49 seconds
# ------------------------------------
# Iteration 78
# ------------------------------------
# Inference time for one sample: 3.48 seconds
# ------------------------------------
# Iteration 79
# ------------------------------------
# Inference time for one sample: 3.46 seconds
# ------------------------------------
# Iteration 80
# ------------------------------------
# Inference time for one sample: 3.45 seconds
# ------------------------------------
# Iteration 81
# ------------------------------------
# Inference time for one sample: 3.46 seconds
# ------------------------------------
# Iteration 82
# ------------------------------------
# Inference time for one sample: 2.20 seconds
# ------------------------------------
# Iteration 83
# ------------------------------------
# Inference time for one sample: 2.69 seconds
# ------------------------------------
# Iteration 84
# ------------------------------------
# Inference time for one sample: 2.69 seconds
# ------------------------------------
# Iteration 85
# ------------------------------------
# Inference time for one sample: 2.70 seconds
# ------------------------------------
# Iteration 86
# ------------------------------------
# Inference time for one sample: 2.75 seconds
# ------------------------------------
# Iteration 87
# ------------------------------------
# Inference time for one sample: 2.61 seconds
# ------------------------------------
# Iteration 88
# ------------------------------------
# Inference time for one sample: 2.54 seconds
# ------------------------------------
# Iteration 89
# ------------------------------------
# Inference time for one sample: 2.58 seconds
# ------------------------------------
# Iteration 90
# ------------------------------------
# Inference time for one sample: 2.51 seconds
# ------------------------------------
# Iteration 91
# ------------------------------------
# Inference time for one sample: 2.57 seconds
# ------------------------------------
# Iteration 92
# ------------------------------------
# Inference time for one sample: 2.54 seconds
# ------------------------------------
# Iteration 93
# ------------------------------------
# Inference time for one sample: 2.52 seconds
# ------------------------------------
# Iteration 94
# ------------------------------------
# Inference time for one sample: 2.75 seconds
# ------------------------------------
# Iteration 95
# ------------------------------------
# Inference time for one sample: 2.31 seconds
# ------------------------------------
# Iteration 96
# ------------------------------------
# Inference time for one sample: 2.31 seconds
# ------------------------------------
# Iteration 97
# ------------------------------------
# Inference time for one sample: 2.34 seconds
# ------------------------------------
# Iteration 98
# ------------------------------------
# Inference time for one sample: 2.55 seconds
# ------------------------------------
# Iteration 99
# ------------------------------------
# Inference time for one sample: 2.23 seconds
# ------------------------------------
# Iteration 100
# ------------------------------------
# Inference time for one sample: 2.32 seconds
# ------------------------------------
# Iteration 101
# ------------------------------------
# Inference time for one sample: 3.16 seconds
# ------------------------------------
# Iteration 102
# ------------------------------------
# Inference time for one sample: 2.89 seconds
# ------------------------------------
# Iteration 103
# ------------------------------------
# Inference time for one sample: 2.84 seconds
# ------------------------------------
# Iteration 104
# ------------------------------------
# Inference time for one sample: 2.91 seconds
# ------------------------------------
# Iteration 105
# ------------------------------------
# Inference time for one sample: 2.84 seconds
# ------------------------------------
# Iteration 106
# ------------------------------------
# Inference time for one sample: 2.60 seconds
# ------------------------------------
# Iteration 107
# ------------------------------------
# Inference time for one sample: 2.64 seconds
# ------------------------------------
# Iteration 108
# ------------------------------------
# Inference time for one sample: 2.43 seconds
# ------------------------------------
# Iteration 109
# ------------------------------------
# Inference time for one sample: 2.37 seconds
# ------------------------------------
# Iteration 110
# ------------------------------------
# Inference time for one sample: 2.47 seconds
# ------------------------------------
# Iteration 111
# ------------------------------------
# Inference time for one sample: 2.43 seconds
# ------------------------------------
# Iteration 112
# ------------------------------------
# Inference time for one sample: 2.30 seconds
# ------------------------------------
# Iteration 113
# ------------------------------------
# Inference time for one sample: 2.36 seconds
# ------------------------------------
# Iteration 114
# ------------------------------------
# Inference time for one sample: 2.44 seconds
# ------------------------------------
# Iteration 115
# ------------------------------------
# Inference time for one sample: 2.27 seconds
# ------------------------------------
# Iteration 116
# ------------------------------------
# Inference time for one sample: 3.30 seconds
# ------------------------------------
# Iteration 117
# ------------------------------------
# Inference time for one sample: 2.93 seconds
# ------------------------------------
# Iteration 118
# ------------------------------------
# Inference time for one sample: 2.93 seconds
# ------------------------------------
# Iteration 119
# ------------------------------------
# Inference time for one sample: 2.94 seconds
# ------------------------------------
# Iteration 120
# ------------------------------------
# Inference time for one sample: 2.95 seconds
# ------------------------------------
# Iteration 121
# ------------------------------------
# Inference time for one sample: 3.34 seconds
# ------------------------------------
# Iteration 122
# ------------------------------------
# Inference time for one sample: 3.42 seconds
# ------------------------------------
# Iteration 123
# ------------------------------------
# Inference time for one sample: 3.41 seconds
# ------------------------------------
# Iteration 124
# ------------------------------------
# Inference time for one sample: 3.40 seconds
# ------------------------------------
# Iteration 125
# ------------------------------------
# Inference time for one sample: 3.36 seconds
# ------------------------------------
# Iteration 126
# ------------------------------------
# Inference time for one sample: 3.54 seconds
# ------------------------------------
# Iteration 127
# ------------------------------------
# Inference time for one sample: 2.95 seconds
# ------------------------------------
# Iteration 128
# ------------------------------------
# Inference time for one sample: 2.63 seconds
# ------------------------------------
# Iteration 129
# ------------------------------------
# Inference time for one sample: 2.70 seconds
# ------------------------------------
# Iteration 130
# ------------------------------------
# Inference time for one sample: 2.68 seconds
# ------------------------------------
# Iteration 131
# ------------------------------------
# Inference time for one sample: 2.67 seconds
# ------------------------------------
# Iteration 132
# ------------------------------------
# Inference time for one sample: 2.92 seconds
# ------------------------------------
# Iteration 133
# ------------------------------------
# Inference time for one sample: 2.93 seconds
# ------------------------------------
# Iteration 134
# ------------------------------------
# Inference time for one sample: 2.93 seconds
# ------------------------------------
# Iteration 135
# ------------------------------------
# Inference time for one sample: 2.80 seconds
# ------------------------------------
# Iteration 136
# ------------------------------------
# Inference time for one sample: 2.74 seconds
# ------------------------------------
# Iteration 137
# ------------------------------------
# Inference time for one sample: 2.82 seconds
# ------------------------------------
# Iteration 138
# ------------------------------------
# Inference time for one sample: 2.76 seconds
# ------------------------------------
# Iteration 139
# ------------------------------------
# Inference time for one sample: 2.85 seconds
# ------------------------------------
# Iteration 140
# ------------------------------------
# Inference time for one sample: 2.62 seconds
# ------------------------------------
# Iteration 141
# ------------------------------------
# Inference time for one sample: 3.27 seconds
# ------------------------------------
# Iteration 142
# ------------------------------------
# Inference time for one sample: 3.16 seconds
# ------------------------------------
# Iteration 143
# ------------------------------------
# Inference time for one sample: 3.14 seconds
# ------------------------------------
# Iteration 144
# ------------------------------------
# Inference time for one sample: 3.17 seconds
# ------------------------------------
# Iteration 145
# ------------------------------------
# Inference time for one sample: 3.17 seconds
# ------------------------------------
# Iteration 146
# ------------------------------------
# Inference time for one sample: 2.77 seconds
# ------------------------------------
# Iteration 147
# ------------------------------------
# Inference time for one sample: 2.84 seconds
# ------------------------------------
# Iteration 148
# ------------------------------------
# Inference time for one sample: 2.80 seconds
# ------------------------------------
# Iteration 149
# ------------------------------------
# Inference time for one sample: 2.82 seconds
# ------------------------------------
# Iteration 150
# ------------------------------------
# Inference time for one sample: 3.20 seconds
# ------------------------------------
# Iteration 151
# ------------------------------------
# Inference time for one sample: 2.24 seconds
# ------------------------------------
# Iteration 152
# ------------------------------------
# Inference time for one sample: 2.26 seconds
# ------------------------------------
# Iteration 153
# ------------------------------------
# Inference time for one sample: 2.26 seconds
# ------------------------------------
# Iteration 154
# ------------------------------------
# Inference time for one sample: 2.46 seconds
# ------------------------------------
# Iteration 155
# ------------------------------------
# Inference time for one sample: 2.42 seconds
# ------------------------------------
# Iteration 156
# ------------------------------------
# Inference time for one sample: 2.43 seconds
# ------------------------------------
# Iteration 157
# ------------------------------------
# Inference time for one sample: 3.09 seconds
# ------------------------------------
# Iteration 158
# ------------------------------------
# Inference time for one sample: 2.72 seconds
# ------------------------------------
# Iteration 159
# ------------------------------------
# Inference time for one sample: 2.78 seconds
# ------------------------------------
# Iteration 160
# ------------------------------------
# Inference time for one sample: 2.75 seconds
# ------------------------------------
# Iteration 161
# ------------------------------------
# Inference time for one sample: 2.72 seconds
# ------------------------------------
# Iteration 162
# ------------------------------------
# Inference time for one sample: 3.10 seconds
# ------------------------------------
# Iteration 163
# ------------------------------------
# Inference time for one sample: 3.03 seconds
# ------------------------------------
# Iteration 164
# ------------------------------------
# Inference time for one sample: 3.01 seconds
# ------------------------------------
# Iteration 165
# ------------------------------------
# Inference time for one sample: 3.23 seconds
# ------------------------------------
# Iteration 166
# ------------------------------------
# Inference time for one sample: 2.54 seconds
# ------------------------------------
# Iteration 167
# ------------------------------------
# Inference time for one sample: 2.61 seconds
# ------------------------------------
# Iteration 168
# ------------------------------------
# Inference time for one sample: 2.57 seconds
# ------------------------------------
# Iteration 169
# ------------------------------------
# Inference time for one sample: 2.57 seconds
# ------------------------------------
# Iteration 170
# ------------------------------------
# Inference time for one sample: 2.74 seconds
# ------------------------------------
# Iteration 171
# ------------------------------------
# Inference time for one sample: 2.66 seconds
# ------------------------------------
# Iteration 172
# ------------------------------------
# Inference time for one sample: 2.62 seconds
# ------------------------------------
# Iteration 173
# ------------------------------------
# Inference time for one sample: 2.66 seconds
# ------------------------------------
# Iteration 174
# ------------------------------------
# Inference time for one sample: 2.69 seconds
# ------------------------------------
# Iteration 175
# ------------------------------------
# Inference time for one sample: 3.08 seconds
# ------------------------------------
# Iteration 176
# ------------------------------------
# Inference time for one sample: 3.06 seconds
# ------------------------------------
# Iteration 177
# ------------------------------------
# Inference time for one sample: 3.03 seconds
# ------------------------------------
# Iteration 178
# ------------------------------------
# Inference time for one sample: 3.07 seconds
# ------------------------------------
# Iteration 179
# ------------------------------------
# Inference time for one sample: 3.06 seconds
# ------------------------------------
# Iteration 180
# ------------------------------------
# Inference time for one sample: 2.77 seconds
# ------------------------------------
# Iteration 181
# ------------------------------------
# Inference time for one sample: 2.76 seconds
# ------------------------------------
# Iteration 182
# ------------------------------------
# Inference time for one sample: 2.73 seconds
# ------------------------------------
# Iteration 183
# ------------------------------------
# Inference time for one sample: 2.74 seconds
# ------------------------------------
# Iteration 184
# ------------------------------------
# Inference time for one sample: 3.19 seconds
# ------------------------------------
# Iteration 185
# ------------------------------------
# Inference time for one sample: 3.24 seconds
# ------------------------------------
# Iteration 186
# ------------------------------------
# Inference time for one sample: 3.28 seconds
# ------------------------------------
# Iteration 187
# ------------------------------------
# Inference time for one sample: 3.27 seconds
# ------------------------------------
# Iteration 188
# ------------------------------------
# Inference time for one sample: 3.99 seconds
# ------------------------------------
# Iteration 189
# ------------------------------------
# Inference time for one sample: 3.94 seconds
# ------------------------------------
# Iteration 190
# ------------------------------------
# Inference time for one sample: 3.93 seconds
# ------------------------------------
# Iteration 191
# ------------------------------------
# Inference time for one sample: 3.93 seconds
# ------------------------------------
# Iteration 192
# ------------------------------------
# Inference time for one sample: 3.95 seconds
# ------------------------------------
# Iteration 193
# ------------------------------------
# Inference time for one sample: 3.89 seconds
# ------------------------------------
# Iteration 194
# ------------------------------------
# Inference time for one sample: 3.91 seconds
# ------------------------------------
# Iteration 195
# ------------------------------------
# Inference time for one sample: 3.92 seconds
# ------------------------------------
# Iteration 196
# ------------------------------------
# Inference time for one sample: 4.32 seconds
# ------------------------------------
# Iteration 197
# ------------------------------------
# Inference time for one sample: 2.48 seconds
# ------------------------------------
# Iteration 198
# ------------------------------------
# Inference time for one sample: 2.41 seconds
# ------------------------------------
# Iteration 199
# ------------------------------------
# Inference time for one sample: 2.42 seconds
# ------------------------------------
# Iteration 200
# ------------------------------------
# Inference time for one sample: 2.45 seconds
# ------------------------------------
# Iteration 201
# ------------------------------------
# Inference time for one sample: 2.24 seconds
# ------------------------------------
# Iteration 202
# ------------------------------------
# Inference time for one sample: 2.26 seconds
# ------------------------------------
# Iteration 203
# ------------------------------------
# Inference time for one sample: 2.41 seconds
# ------------------------------------
# Iteration 204
# ------------------------------------
# Inference time for one sample: 2.39 seconds
# ------------------------------------
# Iteration 205
# ------------------------------------
# Inference time for one sample: 2.39 seconds
# ------------------------------------
# Iteration 206
# ------------------------------------
# Inference time for one sample: 2.19 seconds
# ------------------------------------
# Iteration 207
# ------------------------------------
# Inference time for one sample: 2.52 seconds
# ------------------------------------
# Iteration 208
# ------------------------------------
# Inference time for one sample: 2.49 seconds
# ------------------------------------
# Iteration 209
# ------------------------------------
# Inference time for one sample: 2.48 seconds
# ------------------------------------
# Iteration 210
# ------------------------------------
# Inference time for one sample: 2.51 seconds
# ------------------------------------
# Iteration 211
# ------------------------------------
# Inference time for one sample: 2.69 seconds
# ------------------------------------
# Iteration 212
# ------------------------------------
# Inference time for one sample: 2.73 seconds
# ------------------------------------
# Iteration 213
# ------------------------------------
# Inference time for one sample: 2.78 seconds
# ------------------------------------
# Iteration 214
# ------------------------------------
# Inference time for one sample: 2.82 seconds
# ------------------------------------
# Iteration 215
# ------------------------------------
# Inference time for one sample: 2.76 seconds
# ------------------------------------
# Iteration 216
# ------------------------------------
# Inference time for one sample: 3.16 seconds
# ------------------------------------
# Iteration 217
# ------------------------------------
# Inference time for one sample: 3.08 seconds
# ------------------------------------
# Iteration 218
# ------------------------------------
# Inference time for one sample: 3.11 seconds
# ------------------------------------
# Iteration 219
# ------------------------------------
# Inference time for one sample: 3.41 seconds
# ------------------------------------
# Iteration 220
# ------------------------------------
# Inference time for one sample: 2.24 seconds
# ------------------------------------
# Iteration 221
# ------------------------------------
# Inference time for one sample: 2.66 seconds
# ------------------------------------
# Iteration 222
# ------------------------------------
# Inference time for one sample: 2.66 seconds
# ------------------------------------
# Iteration 223
# ------------------------------------
# Inference time for one sample: 2.62 seconds
# ------------------------------------
# Iteration 224
# ------------------------------------
# Inference time for one sample: 2.68 seconds
# ------------------------------------
# Iteration 225
# ------------------------------------
# Inference time for one sample: 2.95 seconds
# ------------------------------------
# Iteration 226
# ------------------------------------
# Inference time for one sample: 2.92 seconds
# ------------------------------------
# Iteration 227
# ------------------------------------
# Inference time for one sample: 3.27 seconds
# ------------------------------------
# Iteration 228
# ------------------------------------
# Inference time for one sample: 2.25 seconds
# ------------------------------------
# Iteration 229
# ------------------------------------
# Inference time for one sample: 2.75 seconds
# ------------------------------------
# Iteration 230
# ------------------------------------
# Inference time for one sample: 2.53 seconds
# ------------------------------------
# Iteration 231
# ------------------------------------
# Inference time for one sample: 2.50 seconds
# ------------------------------------
# Iteration 232
# ------------------------------------
# Inference time for one sample: 2.47 seconds
# ------------------------------------
# Iteration 233
# ------------------------------------
# Inference time for one sample: 2.51 seconds
# ------------------------------------
# Iteration 234
# ------------------------------------
# Inference time for one sample: 2.48 seconds
# ------------------------------------
# Iteration 235
# ------------------------------------
# Inference time for one sample: 2.39 seconds
# ------------------------------------
# Iteration 236
# ------------------------------------
# Inference time for one sample: 2.42 seconds
# ------------------------------------
# Iteration 237
# ------------------------------------
# Inference time for one sample: 2.53 seconds
# ------------------------------------
# Iteration 238
# ------------------------------------
# Inference time for one sample: 2.45 seconds
# ------------------------------------
# Iteration 239
# ------------------------------------
# Inference time for one sample: 2.45 seconds
# ------------------------------------
# Iteration 240
# ------------------------------------
# Inference time for one sample: 2.45 seconds
# ------------------------------------
# Iteration 241
# ------------------------------------
# Inference time for one sample: 2.48 seconds
# ------------------------------------
# Iteration 242
# ------------------------------------
# Inference time for one sample: 2.74 seconds
# ------------------------------------
# Iteration 243
# ------------------------------------
# Inference time for one sample: 2.49 seconds
# ------------------------------------
# Iteration 244
# ------------------------------------
# Inference time for one sample: 2.45 seconds
# ------------------------------------
# Iteration 245
# ------------------------------------
# Inference time for one sample: 2.44 seconds
# ------------------------------------
# Iteration 246
# ------------------------------------
# Inference time for one sample: 3.09 seconds
# ------------------------------------
# Iteration 247
# ------------------------------------
# Inference time for one sample: 2.90 seconds
# ------------------------------------
# Iteration 248
# ------------------------------------
# Inference time for one sample: 2.97 seconds
# ------------------------------------
# Iteration 249
# ------------------------------------
# Inference time for one sample: 2.87 seconds
# ------------------------------------
# Iteration 250
# ------------------------------------
# Inference time for one sample: 2.90 seconds
# ------------------------------------
# Iteration 251
# ------------------------------------
# Inference time for one sample: 2.63 seconds
# ------------------------------------
# Iteration 252
# ------------------------------------
# Inference time for one sample: 2.67 seconds
# ------------------------------------
# Iteration 253
# ------------------------------------
# Inference time for one sample: 2.34 seconds
# ------------------------------------
# Iteration 254
# ------------------------------------
# Inference time for one sample: 2.30 seconds
# ------------------------------------
# Iteration 255
# ------------------------------------
# Inference time for one sample: 2.63 seconds
# ------------------------------------
# Iteration 256
# ------------------------------------
# Inference time for one sample: 2.54 seconds
# ------------------------------------
# Iteration 257
# ------------------------------------
# Inference time for one sample: 2.49 seconds
# ------------------------------------
# Iteration 258
# ------------------------------------
# Inference time for one sample: 2.52 seconds
# ------------------------------------
# Iteration 259
# ------------------------------------
# Inference time for one sample: 2.51 seconds
# ------------------------------------
# Iteration 260
# ------------------------------------
# Inference time for one sample: 2.34 seconds
# ------------------------------------
# Iteration 261
# ------------------------------------
# Inference time for one sample: 2.84 seconds
# ------------------------------------
# Iteration 262
# ------------------------------------
# Inference time for one sample: 2.54 seconds
# ------------------------------------
# Iteration 263
# ------------------------------------
# Inference time for one sample: 2.52 seconds
# ------------------------------------
# Iteration 264
# ------------------------------------
# Inference time for one sample: 2.52 seconds
# ------------------------------------
# Iteration 265
# ------------------------------------
# Inference time for one sample: 2.49 seconds
# ------------------------------------
# Iteration 266
# ------------------------------------
# Inference time for one sample: 2.69 seconds
# ------------------------------------
# Iteration 267
# ------------------------------------
# Inference time for one sample: 2.99 seconds
# ------------------------------------
# Iteration 268
# ------------------------------------
# Inference time for one sample: 2.46 seconds
# ------------------------------------
# Iteration 269
# ------------------------------------
# Inference time for one sample: 2.44 seconds
# ------------------------------------
# Iteration 270
# ------------------------------------
# Inference time for one sample: 2.44 seconds
# ------------------------------------
# Iteration 271
# ------------------------------------
# Inference time for one sample: 2.47 seconds
# ------------------------------------
# Iteration 272
# ------------------------------------
# Inference time for one sample: 2.61 seconds
# ------------------------------------
# Iteration 273
# ------------------------------------
# Inference time for one sample: 2.35 seconds
# ------------------------------------
# Iteration 274
# ------------------------------------
# Inference time for one sample: 2.38 seconds
# ------------------------------------
# Iteration 275
# ------------------------------------
# Inference time for one sample: 2.37 seconds
# ------------------------------------
# Iteration 276
# ------------------------------------
# Inference time for one sample: 2.38 seconds
# ------------------------------------
# Iteration 277
# ------------------------------------
# Inference time for one sample: 2.56 seconds
# ------------------------------------
# Iteration 278
# ------------------------------------
# Inference time for one sample: 2.61 seconds
# ------------------------------------
# Iteration 279
# ------------------------------------
# Inference time for one sample: 2.58 seconds
# ------------------------------------
# Iteration 280
# ------------------------------------
# Inference time for one sample: 2.57 seconds
# ------------------------------------
# Iteration 281
# ------------------------------------
# Inference time for one sample: 2.54 seconds
# ------------------------------------
# Iteration 282
# ------------------------------------
# Inference time for one sample: 2.87 seconds
# ------------------------------------
# Iteration 283
# ------------------------------------
# Inference time for one sample: 2.82 seconds
# ------------------------------------
# Iteration 284
# ------------------------------------
# Inference time for one sample: 2.82 seconds
# ------------------------------------
# Iteration 285
# ------------------------------------
# Inference time for one sample: 2.81 seconds
# ------------------------------------
# Iteration 286
# ------------------------------------
# Inference time for one sample: 2.76 seconds
# ------------------------------------
# Iteration 287
# ------------------------------------
# Inference time for one sample: 2.63 seconds
# ------------------------------------
# Iteration 288
# ------------------------------------
# Inference time for one sample: 2.61 seconds
# ------------------------------------
# Iteration 289
# ------------------------------------
# Inference time for one sample: 2.40 seconds
# ------------------------------------
# Iteration 290
# ------------------------------------
# Inference time for one sample: 2.47 seconds
# ------------------------------------
# Iteration 291
# ------------------------------------
# Inference time for one sample: 2.73 seconds
# ------------------------------------
# Iteration 292
# ------------------------------------
# Inference time for one sample: 2.62 seconds
# ------------------------------------
# Iteration 293
# ------------------------------------
# Inference time for one sample: 2.63 seconds
# ------------------------------------
# Iteration 294
# ------------------------------------
# Inference time for one sample: 2.62 seconds
# ------------------------------------
# Iteration 295
# ------------------------------------
# Inference time for one sample: 2.69 seconds
# ------------------------------------
# Iteration 296
# ------------------------------------
# Inference time for one sample: 2.51 seconds
# ------------------------------------
# Iteration 297
# ------------------------------------
# Inference time for one sample: 2.49 seconds
# ------------------------------------
# Iteration 298
# ------------------------------------
# Inference time for one sample: 2.47 seconds
# ------------------------------------
# Iteration 299
# ------------------------------------
# Inference time for one sample: 2.50 seconds
# ------------------------------------
# Iteration 300
# ------------------------------------
# Inference time for one sample: 2.54 seconds
# ------------------------------------
# Iteration 301
# ------------------------------------
# Inference time for one sample: 2.33 seconds
# ------------------------------------
# Iteration 302
# ------------------------------------
# Inference time for one sample: 2.24 seconds
# ------------------------------------
# Iteration 303
# ------------------------------------
# Inference time for one sample: 2.43 seconds
# ------------------------------------
# Iteration 304
# ------------------------------------
# Inference time for one sample: 2.40 seconds
# ------------------------------------
# Iteration 305
# ------------------------------------
# Inference time for one sample: 2.44 seconds
# ------------------------------------
# Iteration 306
# ------------------------------------
# Inference time for one sample: 2.42 seconds
# ------------------------------------
# Iteration 307
# ------------------------------------
# Inference time for one sample: 3.02 seconds
# ------------------------------------
# Iteration 308
# ------------------------------------
# Inference time for one sample: 3.05 seconds
# ------------------------------------
# Iteration 309
# ------------------------------------
# Inference time for one sample: 3.04 seconds
# ------------------------------------
# Iteration 310
# ------------------------------------
# Inference time for one sample: 3.03 seconds
# ------------------------------------
# Iteration 311
# ------------------------------------
# Inference time for one sample: 3.61 seconds
# ------------------------------------
# Iteration 312
# ------------------------------------
# Inference time for one sample: 3.48 seconds
# ------------------------------------
# Iteration 313
# ------------------------------------
# Inference time for one sample: 3.54 seconds
# ------------------------------------
# Iteration 314
# ------------------------------------
# Inference time for one sample: 3.44 seconds
# ------------------------------------
# Iteration 315
# ------------------------------------
# Inference time for one sample: 3.46 seconds
# ------------------------------------
# Iteration 316
# ------------------------------------
# Inference time for one sample: 3.58 seconds
# ------------------------------------
# Iteration 317
# ------------------------------------
# Inference time for one sample: 3.57 seconds
# ------------------------------------
# Iteration 318
# ------------------------------------
# Inference time for one sample: 3.08 seconds
# ------------------------------------
# Iteration 319
# ------------------------------------
# Inference time for one sample: 3.08 seconds
# ------------------------------------
# Iteration 320
# ------------------------------------
# Inference time for one sample: 3.07 seconds
# ------------------------------------
# Iteration 321
# ------------------------------------
# Inference time for one sample: 3.04 seconds
# ------------------------------------
# Iteration 322
# ------------------------------------
# Inference time for one sample: 2.78 seconds
# ------------------------------------
# Iteration 323
# ------------------------------------
# Inference time for one sample: 2.70 seconds
# ------------------------------------
# Iteration 324
# ------------------------------------
# Inference time for one sample: 2.72 seconds
# ------------------------------------
# Iteration 325
# ------------------------------------
# Inference time for one sample: 2.78 seconds
# ------------------------------------
# Iteration 326
# ------------------------------------
# Inference time for one sample: 2.31 seconds
# ------------------------------------
# Iteration 327
# ------------------------------------
# Inference time for one sample: 2.35 seconds
# ------------------------------------
# Iteration 328
# ------------------------------------
# Inference time for one sample: 2.20 seconds
# ------------------------------------
# Iteration 329
# ------------------------------------
# Inference time for one sample: 3.35 seconds
# ------------------------------------
# Iteration 330
# ------------------------------------
# Inference time for one sample: 3.39 seconds
# ------------------------------------
# Iteration 331
# ------------------------------------
# Inference time for one sample: 3.34 seconds
# ------------------------------------
# Iteration 332
# ------------------------------------
# Inference time for one sample: 3.42 seconds
# ------------------------------------
# Iteration 333
# ------------------------------------
# Inference time for one sample: 3.08 seconds
# ------------------------------------
# Iteration 334
# ------------------------------------
# Inference time for one sample: 2.95 seconds
# ------------------------------------
# Iteration 335
# ------------------------------------
# Inference time for one sample: 2.91 seconds
# ------------------------------------
# Iteration 336
# ------------------------------------
# Inference time for one sample: 2.96 seconds
# ------------------------------------
# Iteration 337
# ------------------------------------
# Inference time for one sample: 3.03 seconds
# ------------------------------------
# Iteration 338
# ------------------------------------
# Inference time for one sample: 2.99 seconds
# ------------------------------------
# Iteration 339
# ------------------------------------
# Inference time for one sample: 3.32 seconds
# ------------------------------------
# Iteration 340
# ------------------------------------
# Inference time for one sample: 2.76 seconds
# ------------------------------------
# Iteration 341
# ------------------------------------
# Inference time for one sample: 2.78 seconds
# ------------------------------------
# Iteration 342
# ------------------------------------
# Inference time for one sample: 2.85 seconds
# ------------------------------------
# Iteration 343
# ------------------------------------
# Inference time for one sample: 2.74 seconds
# ------------------------------------
# Iteration 344
# ------------------------------------
# Inference time for one sample: 3.18 seconds
# ------------------------------------
# Iteration 345
# ------------------------------------
# Inference time for one sample: 3.05 seconds
# ------------------------------------
# Iteration 346
# ------------------------------------
# Inference time for one sample: 3.07 seconds
# ------------------------------------
# Iteration 347
# ------------------------------------
# Inference time for one sample: 3.11 seconds
# ------------------------------------
# Iteration 348
# ------------------------------------
# Inference time for one sample: 3.13 seconds
# ------------------------------------
# Iteration 349
# ------------------------------------
# Inference time for one sample: 2.65 seconds
# ------------------------------------
# Iteration 350
# ------------------------------------
# Inference time for one sample: 2.61 seconds
# ------------------------------------
# Iteration 351
# ------------------------------------
# Inference time for one sample: 2.63 seconds
# ------------------------------------
# Iteration 352
# ------------------------------------
# Inference time for one sample: 2.64 seconds
# ------------------------------------
# Iteration 353
# ------------------------------------
# Inference time for one sample: 2.82 seconds
# ------------------------------------
# Iteration 354
# ------------------------------------
# Inference time for one sample: 2.83 seconds
# ------------------------------------
# Iteration 355
# ------------------------------------
# Inference time for one sample: 2.88 seconds
# ------------------------------------
# Iteration 356
# ------------------------------------
# Inference time for one sample: 2.91 seconds
# ------------------------------------
# Iteration 357
# ------------------------------------
# Inference time for one sample: 2.89 seconds
# ------------------------------------
# Iteration 358
# ------------------------------------
# Inference time for one sample: 2.97 seconds
# ------------------------------------
# Iteration 359
# ------------------------------------
# Inference time for one sample: 2.92 seconds
# ------------------------------------
# Iteration 360
# ------------------------------------
# Inference time for one sample: 2.84 seconds
# ------------------------------------
# Iteration 361
# ------------------------------------
# Inference time for one sample: 2.68 seconds
# ------------------------------------
# Iteration 362
# ------------------------------------
# Inference time for one sample: 2.66 seconds
# ------------------------------------
# Iteration 363
# ------------------------------------
# Inference time for one sample: 3.04 seconds
# ------------------------------------
# Iteration 364
# ...
# Inference time for one sample: 2.64 seconds
# ------------------------------------
# Iteration 393
# ------------------------------------
# Inference time for one sample: 2.69 seconds
# ------------------------------------
# Iteration 394
# ------------------------------------
# Inference time for one sample: 2.92 seconds
# ------------------------------------
# Iteration 395
# ------------------------------------
# Inference time for one sample: 2.92 seconds
# ------------------------------------
# Iteration 396
# ------------------------------------
# Inference time for one sample: 2.94 seconds
# ------------------------------------
# Iteration 397
# ------------------------------------
# Inference time for one sample: 2.30 seconds
# ------------------------------------
# Iteration 398
# ------------------------------------
# Inference time for one sample: 2.26 seconds
# ------------------------------------
# Iteration 399
# ------------------------------------
# Inference time for one sample: 2.87 seconds
# ------------------------------------
# Iteration 400
# ------------------------------------
# Inference time for one sample: 2.52 seconds
# ------------------------------------
# Iteration 401
# ------------------------------------
# Inference time for one sample: 2.61 seconds
# ------------------------------------
# Iteration 402
# ------------------------------------
# Inference time for one sample: 2.53 seconds
# ------------------------------------
# Iteration 403
# ------------------------------------
# Inference time for one sample: 2.59 seconds
# ------------------------------------
# Iteration 404
# ------------------------------------
# Inference time for one sample: 2.67 seconds
# ------------------------------------
# Iteration 405
# ------------------------------------
# Inference time for one sample: 2.99 seconds
# ------------------------------------
# Iteration 406
# ------------------------------------
# Inference time for one sample: 2.98 seconds
# ------------------------------------
# Iteration 407
# ------------------------------------
# Inference time for one sample: 2.93 seconds
# ------------------------------------
# Iteration 408
# ------------------------------------
# Inference time for one sample: 2.93 seconds
# ------------------------------------
# Iteration 409
# ------------------------------------
# Inference time for one sample: 2.92 seconds
# ------------------------------------
# Iteration 410
# ------------------------------------
# Inference time for one sample: 2.68 seconds
# ------------------------------------
# Iteration 411
# ------------------------------------
# Inference time for one sample: 2.66 seconds
# ------------------------------------
# Iteration 412
# ------------------------------------
# Inference time for one sample: 2.73 seconds
# ------------------------------------
# Iteration 413
# ------------------------------------
# Inference time for one sample: 2.85 seconds
# ------------------------------------
# Iteration 414
# ------------------------------------
# Inference time for one sample: 2.89 seconds
# ------------------------------------
# Iteration 415
# ------------------------------------
# Inference time for one sample: 2.85 seconds
# ------------------------------------
# Iteration 416
# ------------------------------------
# Inference time for one sample: 2.81 seconds
# ------------------------------------
# Iteration 417
# ------------------------------------
# Inference time for one sample: 2.72 seconds
# ------------------------------------
# Iteration 418
# ------------------------------------
# Inference time for one sample: 2.62 seconds
# ------------------------------------
# Iteration 419
# ------------------------------------
# Inference time for one sample: 2.60 seconds
# ------------------------------------
# Iteration 420
# ------------------------------------
# Inference time for one sample: 2.78 seconds
# ------------------------------------
# Iteration 421
# ------------------------------------
# Inference time for one sample: 2.76 seconds
# ------------------------------------
# Iteration 422
# ------------------------------------
# Inference time for one sample: 2.77 seconds
# ------------------------------------
# Iteration 423
# ------------------------------------
# Inference time for one sample: 2.81 seconds
# ------------------------------------
# Iteration 424
# ------------------------------------
# Inference time for one sample: 2.69 seconds
# ------------------------------------
# Iteration 425
# ------------------------------------
# Inference time for one sample: 2.62 seconds
# ------------------------------------
# Iteration 426
# ------------------------------------
# Inference time for one sample: 2.87 seconds
# ------------------------------------
# Iteration 427
# ------------------------------------
# Inference time for one sample: 3.52 seconds
# ------------------------------------
# Iteration 428
# ------------------------------------
# Inference time for one sample: 3.30 seconds
# ------------------------------------
# Iteration 429
# ------------------------------------
# Inference time for one sample: 3.27 seconds
# ------------------------------------
# Iteration 430
# ------------------------------------
# Inference time for one sample: 3.26 seconds
# ------------------------------------
# Iteration 431
# ------------------------------------
# Inference time for one sample: 3.30 seconds
# ------------------------------------
# Iteration 432
# ------------------------------------
# Inference time for one sample: 3.93 seconds
# ------------------------------------
# Iteration 433
# ------------------------------------
# Inference time for one sample: 3.91 seconds
# ------------------------------------
# Iteration 434
# ------------------------------------
# Inference time for one sample: 3.95 seconds
# ------------------------------------
# Iteration 435
# ------------------------------------
# Inference time for one sample: 3.91 seconds
# ------------------------------------
# Iteration 436
# ------------------------------------
# Inference time for one sample: 3.92 seconds
# ------------------------------------
# Iteration 437
# ------------------------------------
# Inference time for one sample: 3.91 seconds
# ------------------------------------
# Iteration 438
# ------------------------------------
# Inference time for one sample: 3.92 seconds
# ------------------------------------
# Iteration 439
# ------------------------------------
# Inference time for one sample: 3.94 seconds
# ------------------------------------
# Iteration 440
# ------------------------------------
# Inference time for one sample: 4.23 seconds
# ------------------------------------
# Iteration 441
# ------------------------------------
# Inference time for one sample: 2.28 seconds
# ------------------------------------
# Iteration 442
# ------------------------------------
# Inference time for one sample: 2.39 seconds
# ------------------------------------
# Iteration 443
# ------------------------------------
# Inference time for one sample: 2.40 seconds
# ------------------------------------
# Iteration 444
# ------------------------------------
# Inference time for one sample: 2.36 seconds
# ------------------------------------
# Iteration 445
# ------------------------------------
# Inference time for one sample: 2.86 seconds
# ------------------------------------
# Iteration 446
# ------------------------------------
# Inference time for one sample: 2.60 seconds
# ------------------------------------
# Iteration 447
# ------------------------------------
# Inference time for one sample: 2.64 seconds
# ------------------------------------
# Iteration 448
# ------------------------------------
# Inference time for one sample: 2.63 seconds
# ------------------------------------
# Iteration 449
# ------------------------------------
# Inference time for one sample: 2.64 seconds
# ------------------------------------
# Iteration 450
# ------------------------------------
# Inference time for one sample: 2.47 seconds
# ------------------------------------
# Iteration 451
# ------------------------------------
# Inference time for one sample: 2.24 seconds
# ------------------------------------
# Iteration 452
# ------------------------------------
# Inference time for one sample: 2.88 seconds
# ------------------------------------
# Iteration 453
# ------------------------------------
# Inference time for one sample: 2.57 seconds
# ------------------------------------
# Iteration 454
# ------------------------------------
# Inference time for one sample: 2.53 seconds
# ------------------------------------
# Iteration 455
# ------------------------------------
# Inference time for one sample: 2.53 seconds
# ------------------------------------
# Iteration 456
# ------------------------------------
# Inference time for one sample: 2.50 seconds
# ------------------------------------
# Iteration 457
# ------------------------------------
# Inference time for one sample: 2.67 seconds
# ------------------------------------
# Iteration 458
# ------------------------------------
# Inference time for one sample: 2.74 seconds
# ------------------------------------
# Iteration 459
# ------------------------------------
# Inference time for one sample: 2.69 seconds
# ------------------------------------
# Iteration 460
# ------------------------------------
# Inference time for one sample: 2.69 seconds
# ------------------------------------
# Iteration 461
# ------------------------------------
# Inference time for one sample: 2.64 seconds
# ------------------------------------
# Iteration 462
# ------------------------------------
# Inference time for one sample: 2.66 seconds
# ------------------------------------
# Iteration 463
# ------------------------------------
# Inference time for one sample: 2.86 seconds
# ------------------------------------
# Iteration 464
# ------------------------------------
# Inference time for one sample: 2.92 seconds
# ------------------------------------
# Iteration 465
# ------------------------------------
# Inference time for one sample: 3.11 seconds
# ------------------------------------
# Iteration 466
# ------------------------------------
# Inference time for one sample: 2.59 seconds
# ------------------------------------
# Iteration 467
# ------------------------------------
# Inference time for one sample: 2.53 seconds
# ------------------------------------
# Iteration 468
# ------------------------------------
# Inference time for one sample: 2.58 seconds
# ------------------------------------
# Iteration 469
# ------------------------------------
# Inference time for one sample: 2.56 seconds
# ------------------------------------
# Iteration 470
# ------------------------------------
# Inference time for one sample: 3.12 seconds
# ------------------------------------
# Iteration 471
# ------------------------------------
# Inference time for one sample: 3.17 seconds
# ------------------------------------
# Iteration 472
# ------------------------------------
# Inference time for one sample: 3.07 seconds
# ------------------------------------
# Iteration 473
# ------------------------------------
# Inference time for one sample: 3.11 seconds
# ------------------------------------
# Iteration 474
# ------------------------------------
# Inference time for one sample: 2.90 seconds
# ------------------------------------
# Iteration 475
# ------------------------------------
# Inference time for one sample: 2.79 seconds
# ------------------------------------
# Iteration 476
# ------------------------------------
# Inference time for one sample: 2.89 seconds
# ------------------------------------
# Iteration 477
# ------------------------------------
# Inference time for one sample: 2.77 seconds
# ------------------------------------
# Iteration 478
# ------------------------------------
# Inference time for one sample: 2.85 seconds
# ------------------------------------
# Iteration 479
# ------------------------------------
# Inference time for one sample: 2.68 seconds
# ------------------------------------
# Iteration 480
# ------------------------------------
# Inference time for one sample: 2.70 seconds
# ------------------------------------
# Iteration 481
# ------------------------------------
# Inference time for one sample: 2.68 seconds
# ------------------------------------
# Iteration 482
# ------------------------------------
# Inference time for one sample: 2.71 seconds
# ------------------------------------
# Iteration 483
# ------------------------------------
# Inference time for one sample: 2.56 seconds
# ------------------------------------
# Iteration 484
# ------------------------------------
# Inference time for one sample: 2.72 seconds
# ------------------------------------
# Iteration 485
# ------------------------------------
# Inference time for one sample: 2.71 seconds
# ------------------------------------
# Iteration 486
# ------------------------------------
# Inference time for one sample: 2.72 seconds
# ------------------------------------
# Iteration 487
# ------------------------------------
# Inference time for one sample: 2.74 seconds
# ------------------------------------
# Iteration 488
# ------------------------------------
# Inference time for one sample: 2.89 seconds
# ------------------------------------
# Iteration 489
# ------------------------------------
# Inference time for one sample: 2.55 seconds
# ------------------------------------
# Iteration 490
# ------------------------------------
# Inference time for one sample: 2.64 seconds
# ------------------------------------
# Iteration 491
# ------------------------------------
# Inference time for one sample: 2.59 seconds
# ------------------------------------
# Iteration 492
# ------------------------------------
# Inference time for one sample: 2.59 seconds
# ------------------------------------
# Iteration 493
# ------------------------------------
# Inference time for one sample: 2.67 seconds
# ------------------------------------
# Iteration 494
# ------------------------------------
# Inference time for one sample: 2.91 seconds
# ------------------------------------
# Iteration 495
# ------------------------------------
# Inference time for one sample: 2.84 seconds
# ------------------------------------
# Iteration 496
# ------------------------------------
# Inference time for one sample: 2.95 seconds
# ------------------------------------
# Iteration 497
# ------------------------------------
# Inference time for one sample: 2.89 seconds
# ------------------------------------
# Iteration 498
# ------------------------------------
# Inference time for one sample: 2.89 seconds
# ------------------------------------
# Iteration 499
# ------------------------------------
# Inference time for one sample: 2.88 seconds
# ------------------------------------
# Iteration 500
# ------------------------------------
# Inference time for one sample: 2.86 seconds
# ------------------------------------
# Iteration 501
# ------------------------------------
# Inference time for one sample: 3.25 seconds
# ------------------------------------
# Iteration 502
# ------------------------------------
# Inference time for one sample: 3.27 seconds
# ------------------------------------
# Iteration 503
# ------------------------------------
# Inference time for one sample: 3.23 seconds
# ------------------------------------
# Iteration 504
# ------------------------------------
# Inference time for one sample: 3.24 seconds
# ------------------------------------
# Iteration 505
# ------------------------------------
# Inference time for one sample: 3.31 seconds
# ------------------------------------
# Iteration 506
# ------------------------------------
# Inference time for one sample: 2.20 seconds
# ------------------------------------
# Iteration 507
# ------------------------------------
# Inference time for one sample: 3.58 seconds
# ------------------------------------
# Iteration 508
# ------------------------------------
# Inference time for one sample: 3.26 seconds
# ------------------------------------
# Iteration 509
# ------------------------------------
# Inference time for one sample: 3.29 seconds
# ------------------------------------
# Iteration 510
# ------------------------------------
# Inference time for one sample: 3.28 seconds
# ------------------------------------
# Iteration 511
# ------------------------------------
# Inference time for one sample: 3.24 seconds
# ------------------------------------
# Iteration 512
# ------------------------------------
# Inference time for one sample: 3.90 seconds
# ------------------------------------
# Iteration 513
# ------------------------------------

# %% [markdown]
# **Infer one sample at a time**

# %%
# Per sample inference
# init_time = time.time()

# if with_labels:
#     pred_labels_list, true_labels_list, full_output, correct = evaluate_with_label(dataset)
# else:
#     pred_labels_list, true_labels_list, full_output = evaluate_without_label(dataset)

# final_time = time.time()
# print("Total time taken for {} samples = {:.2f} seconds.".format(n, final_time - init_time))

# %% [markdown]
# #### **Save input to next module and all results**

# %% [markdown]
# **Create the input to the next module as a list of JSON objects:**
# ```
# [
#     {
#         "conversation_ID": 1374,
#         "conversation": [
#                 {
#                     "utterance_ID": 1,
#                     "text": "Please do not do that again . It is a horrible sound .",
#                     "speaker": "Chandler",
#                     "video_name": "dia1375utt1.mp4",
#                     "emotion": "anger"
#                 },
#                 {
#                     "utterance_ID": 2,
#                     "text": "Please do not do that again . It is a horrible sound .",
#                     "speaker": "Chandler",
#                     "video_name": "dia1375utt1.mp4",
#                     "emotion": "anger"
#                 },
#             ]
#         ]
#     },
# ]
# ```

# %%
# Marking empty predictions as neutral
# Can use visual modality for these
for i in range(n):
    if pred_labels_list[i] not in ["anger","fear","surprise","joy","sadness","disgust","neutral"]:
        pred_labels_list[i] = "neutral"
#     print("Predicted: ", pred_labels_list[i])
#     print("Baseline: ", true_labels_list[i])

# %%
i = 0
for conv in data:
    for utt in conv["conversation"]:
        utt["emotion"]=pred_labels_list[i]
        i += 1
save_file = eval_results_folder+"/emotion_labelled_data.json"
with open(save_file, 'w') as f:
    f.write(json.dumps(data))

# %% [markdown]
# #### **Calculate F1-scores**

# %%
if with_labels:
    # Find F1-scores
    from sklearn.metrics import classification_report
    import numpy as np
    
    emotion_labels = ['anger','disgust','fear','sadness','neutral','joy','surprise']
    emotion_index = dict(zip(emotion_labels, range(len(emotion_labels))))
   
    rep = classification_report(true_labels_list, pred_labels_list, labels=emotion_labels, output_dict=True,zero_division=0)
    print(rep)

# %% [markdown]
# #### **For Colab: Download files and disconnect**

# %%
# # Download the results before you lose them
# from google.colab import files
# import os

# dir_to_zip = eval_results_folder
# output_filename = eval_results_folder+".zip"
# delete_dir_after_download = "No"

# os.system( "zip -r {} {}".format( output_filename , dir_to_zip ) )

# if delete_dir_after_download == "Yes":
#     os.system( "rm -r {}".format( dir_to_zip ) )

# files.download( output_filename )

# %%
# # And disconnect before runnning out of compute units
# from google.colab import runtime
# runtime.unassign()
